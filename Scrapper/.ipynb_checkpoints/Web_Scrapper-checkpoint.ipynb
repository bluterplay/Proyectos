# %% [markdown]
# # Modulos

# %%
import time
import requests
import numpy as np
import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# %% [markdown]
# # Funciones

# %%
def extract_results(driver):
    dc= {"Title":[], "Link":[], "Description":[]}
    results = driver.find_elements(By.XPATH, "//td[@class='bmtextview']")
    
    for result in results:
        link_element = result.find_element(By.TAG_NAME, "a")
        description_element = result.find_element(By.CLASS_NAME, "bbm_result_fieldvalue")

        title = link_element.text
        link = link_element.get_attribute("href")
        description = description_element.text

        dc["Title"].append(title)
        dc["Link"].append(link)
        dc["Description"].append(description)

    return pd.DataFrame(dc)

# %%
def download_file(url, file_name):

    response = requests.get(url)
    if response.status_code == 200:
        
        with open(file_name, 'wb') as file:
            file.write(response.content)
            print(f"Archivo descargado: {file_name}")
    else:
        print(f"Error al descargar el archivo: {response.status_code}")

# %% [markdown]
# # Lectura de datos

# %% [markdown]
# ## Resultados Pagina Web

# %%
url = "https://www.banxico.org.mx/AplBusquedasBM2/bgenwww_es.jsp"
search_term = "tpv"

# %%
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

search_bar = driver.find_element(By.NAME, "_userquery")
search_bar.send_keys(search_term)
search_bar.send_keys(Keys.RETURN)
time.sleep(5)

ls_data = []
ls_data.append(extract_results(driver))

while True:
    try:
        next_button = driver.find_element(By.XPATH, "//a[contains(text(), 'Siguiente')]")
        next_button.click()
        time.sleep(5)  # Esperar a que los resultados carguen
        ls_data.append(extract_results(driver))
    except:
        break  # Salir del bucle si no hay más páginas

driver.quit()

# %%
all_searchs = pd.concat(ls_data, ignore_index=True)

# %% [markdown]
# ### Procesamiento

# %%
all_searchs["Type"] = all_searchs["Title"].apply(lambda x: (x.split(",")[-1]).strip())
all_searchs["Title"] = all_searchs["Title"].apply(lambda x: " ".join(x.split(",")[:-1]))
all_searchs.Type.unique()
# Out:
# array(['SIE', 'pdf', 'html'], dtype=object)

# %%
all_searchs.sample(5)
# Out:
#                                                  Title  \
# 54                                             Hoteles
# 110                                              Peaje
# 129  2011-09 Regulación de comisiones de cajero en ...
# 49   Informe anual de cumplimiento de la Ley para l...
# 105  Modificaciones a las Reglas conjuntas Banco de...
#
#                                                   Link  \
# 54   https://www.banxico.org.mx/servicios/tasas-de-...
# 110  https://www.banxico.org.mx/servicios/tasas-de-...
# 129  https://www.banxico.org.mx/publicaciones-y-pre...
# 49   https://www.banxico.org.mx/publicaciones-y-pre...
# 105  https://www.banxico.org.mx/marco-normativo/nor...
#
#                                            Description Type
# 54   Hoteles. Hoteles. Tasas de descuento por giro ...  pdf
# 110  Peaje. Peaje. Tasas de descuento por giro de n...  pdf
# 129  2011-09 Regulación de comisiones de cajero en ...  pdf
# 49   Informe anual de cumplimiento de la Ley para l...  pdf
# 105  Modificaciones a las Reglas conjuntas Banco de...  pdf

# %%
all_searchs[all_searchs.Title=='Hoteles'].iloc[0,1]
# Out:
# 'https://www.banxico.org.mx/servicios/tasas-de-descuento-para-tarjetas-de-credito-por-gi/%7B4B7FCB63-8D2C-F86D-578D-130144A51CD5%7D.pdf'

# %%
all_searchs["Download"] = all_searchs["Link"].apply(lambda x: 1 if "tasas-de-descuento" in x else 0)
all_searchs["Card"] = np.where(all_searchs["Download"]==1,
                               np.where(all_searchs["Link"].str.contains("credito"),"Credito","Debito"),"No Aplica")

# %%
all_searchs["File_name"] = np.where(all_searchs["Download"]==1,"Descuento " +all_searchs["Card"] +" " +all_searchs["Title"] +"."+ all_searchs["Type"], '' )

# %%
all_searchs[all_searchs.Download==1]
# Out:
#                          Title  \
# 0           Agencias de viajes
# 1           Agencias de viajes
# 2                  Agregadores
# 3                  Agregadores
# 4                 Aseguradoras
# 5                 Aseguradoras
# 6                 Beneficencia
# 7                 Beneficencia
# 8     Colegios y universidades
# 9     Colegios y universidades
# 10               Comida rápida
# 11               Comida rápida
# 12            Educación básica
# 13            Educación básica
# 14             Entretenimiento
# 15             Entretenimiento
# 16            Estacionamientos
# 17            Estacionamientos
# 18                   Farmacias
# 19                   Farmacias
# 20                 Gasolineras
# 21                 Gasolineras
# 22                    Gobierno
# 23                    Gobierno
# 24                  Hospitales
# 25                  Hospitales
# 26                     Hoteles
# 27                     Hoteles
# 28                 Misceláneas
# 29                 Misceláneas
# 30         Médicos y dentistas
# 31         Médicos y dentistas
# 32                       Otros
# 33                       Otros
# 34                       Peaje
# 35                       Peaje
# 36   Refacciones y ferreterías
# 37   Refacciones y ferreterías
# 38              Renta de autos
# 39              Renta de autos
# 40                Restaurantes
# 41                Restaurantes
# 42          Salones de belleza
# 43          Salones de belleza
# 44               Supermercados
# 45               Supermercados
# 46          Telecomunicaciones
# 47          Telecomunicaciones
# 48            Transporte aéreo
# 49            Transporte aéreo
# 50  Ventas al detalle (Retail)
# 51  Ventas al detalle (Retail)
#
#                                                  Link  \
# 0   https://www.banxico.org.mx/servicios/tasas-de-...
# 1   https://www.banxico.org.mx/servicios/tasas-de-...
# 2   https://www.banxico.org.mx/servicios/tasas-de-...
# 3   https://www.banxico.org.mx/servicios/tasas-de-...
# 4   https://www.banxico.org.mx/servicios/tasas-de-...
# 5   https://www.banxico.org.mx/servicios/tasas-de-...
# 6   https://www.banxico.org.mx/servicios/tasas-de-...
# 7   https://www.banxico.org.mx/servicios/tasas-de-...
# 8   https://www.banxico.org.mx/servicios/tasas-de-...
# 9   https://www.banxico.org.mx/servicios/tasas-de-...
# 10  https://www.banxico.org.mx/servicios/tasas-de-...
# 11  https://www.banxico.org.mx/servicios/tasas-de-...
# 12  https://www.banxico.org.mx/servicios/tasas-de-...
# 13  https://www.banxico.org.mx/servicios/tasas-de-...
# 14  https://www.banxico.org.mx/servicios/tasas-de-...
# 15  https://www.banxico.org.mx/servicios/tasas-de-...
# 16  https://www.banxico.org.mx/servicios/tasas-de-...
# 17  https://www.banxico.org.mx/servicios/tasas-de-...
# 18  https://www.banxico.org.mx/servicios/tasas-de-...
# 19  https://www.banxico.org.mx/servicios/tasas-de-...
